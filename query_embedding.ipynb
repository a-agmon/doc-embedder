# %%
# %pip install lancedb
# %pip install pandas
# %pip install pyarrow
# Out:
# Requirement already satisfied: lancedb in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (0.9.0)
# Requirement already satisfied: deprecation in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from lancedb) (2.1.0)
# Requirement already satisfied: pylance==0.13.0 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from lancedb) (0.13.0)
# Requirement already satisfied: ratelimiter~=1.0 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from lancedb) (1.2.0.post0)
# Requirement already satisfied: requests>=2.31.0 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from lancedb) (2.31.0)
# Requirement already satisfied: retry>=0.9.2 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from lancedb) (0.9.2)
# Requirement already satisfied: tqdm>=4.27.0 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from lancedb) (4.66.4)
# Requirement already satisfied: pydantic>=1.10 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from lancedb) (2.5.2)
# Requirement already satisfied: attrs>=21.3.0 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from lancedb) (23.1.0)
# Requirement already satisfied: packaging in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from lancedb) (23.2)
# Requirement already satisfied: cachetools in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from lancedb) (5.3.3)
# Requirement already satisfied: overrides>=0.7 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from lancedb) (7.4.0)
# Requirement already satisfied: pyarrow<15.0.1,>=12 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from pylance==0.13.0->lancedb) (15.0.0)
# Requirement already satisfied: numpy>=1.22 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from pylance==0.13.0->lancedb) (1.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from pydantic>=1.10->lancedb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from pydantic>=1.10->lancedb) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from pydantic>=1.10->lancedb) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from requests>=2.31.0->lancedb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from requests>=2.31.0->lancedb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from requests>=2.31.0->lancedb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from requests>=2.31.0->lancedb) (2023.11.17)
# Requirement already satisfied: decorator>=3.4.2 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from retry>=0.9.2->lancedb) (5.1.1)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from retry>=0.9.2->lancedb) (1.11.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyarrow in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (15.0.0)
# Requirement already satisfied: numpy<2,>=1.16.6 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from pyarrow) (1.26.4)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import lancedb
import pandas as pd
import pyarrow as pa

uri = "data/vecdb"
db = lancedb.connect(uri)

# %%
print(db.table_names())
tbl = db.open_table("vectors_table_1")
# Out:
# ['vectors_table_1']

# %%
tbl.count_rows()
# Out:
# 2224

# %%
tbl.search(None).select(["filename"]).to_pandas()
# Out:
#                                       filename
# 0   embedding_files/embedding_content_1181.txt
# 1  embedding_files/embedding_content_11031.txt
# 2  embedding_files/embedding_content_11196.txt
# 3  embedding_files/embedding_content_10560.txt
# 4  embedding_files/embedding_content_11682.txt
# 5   embedding_files/embedding_content_1034.txt
# 6  embedding_files/embedding_content_11190.txt
# 7  embedding_files/embedding_content_11136.txt
# 8  embedding_files/embedding_content_11189.txt
# 9  embedding_files/embedding_content_10287.txt

# %%
# %pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Obtaining dependency information for sentence_transformers from https://files.pythonhosted.org/packages/58/4b/922436953394e1bfda05e4bf1fe0e80f609770f256c59a9df7a9254f3e0d/sentence_transformers-3.0.1-py3-none-any.whl.metadata
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Collecting transformers<5.0.0,>=4.34.0 (from sentence_transformers)
#   Obtaining dependency information for transformers<5.0.0,>=4.34.0 from https://files.pythonhosted.org/packages/20/5c/244db59e074e80248fdfa60495eeee257e4d97c3df3487df68be30cd60c8/transformers-4.42.3-py3-none-any.whl.metadata
#   Downloading transformers-4.42.3-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 682.1 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: tqdm in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from sentence_transformers) (4.66.4)
# Collecting torch>=1.11.0 (from sentence_transformers)
#   Obtaining dependency information for torch>=1.11.0 from https://files.pythonhosted.org/packages/49/b6/1a2e3d43d4bc4ad7a4575b3745d707a68d5ed00ba263b205b6281bdd0921/torch-2.3.1-cp312-none-macosx_11_0_arm64.whl.metadata
#   Downloading torch-2.3.1-cp312-none-macosx_11_0_arm64.whl.metadata (26 kB)
# Requirement already satisfied: numpy in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from sentence_transformers) (1.26.4)
# Collecting scikit-learn (from sentence_transformers)
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/d5/2c/734fc9269bdb6768905ac41b82d75264b26925b1e462f4ebf45fe4f17646/scikit_learn-1.5.1-cp312-cp312-macosx_12_0_arm64.whl.metadata
#   Downloading scikit_learn-1.5.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (12 kB)
# Collecting scipy (from sentence_transformers)
#   Obtaining dependency information for scipy from https://files.pythonhosted.org/packages/09/70/5e756d3f90fe3fff64d1550db0fa6bb9eb76eedd084c568618f93441f08c/scipy-1.14.0-cp312-cp312-macosx_14_0_arm64.whl.metadata
#   Downloading scipy-1.14.0-cp312-cp312-macosx_14_0_arm64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 2.3 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.15.1 (from sentence_transformers)
#   Obtaining dependency information for huggingface-hub>=0.15.1 from https://files.pythonhosted.org/packages/69/d6/73f9d1b7c4da5f0544bc17680d0fa9932445423b90cd38e1ee77d001a4f5/huggingface_hub-0.23.4-py3-none-any.whl.metadata
#   Downloading huggingface_hub-0.23.4-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: Pillow in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from sentence_transformers) (10.3.0)
# Collecting filelock (from huggingface-hub>=0.15.1->sentence_transformers)
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/ae/f0/48285f0262fe47103a4a45972ed2f9b93e4c80b8fd609fa98da78b2a5706/filelock-3.15.4-py3-none-any.whl.metadata
#   Downloading filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.1)
# Requirement already satisfied: requests in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.8.0)
# Collecting sympy (from torch>=1.11.0->sentence_transformers)
#   Obtaining dependency information for sympy from https://files.pythonhosted.org/packages/61/53/e18c8c97d0b2724d85c9830477e3ebea3acf1dcdc6deb344d5d9c93a9946/sympy-1.12.1-py3-none-any.whl.metadata
#   Downloading sympy-1.12.1-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.11.0->sentence_transformers)
#   Obtaining dependency information for networkx from https://files.pythonhosted.org/packages/38/e9/5f72929373e1a0e8d142a130f3f97e6ff920070f87f91c4e13e40e0fba5a/networkx-3.3-py3-none-any.whl.metadata
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: jinja2 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from torch>=1.11.0->sentence_transformers) (3.1.2)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.34.0->sentence_transformers)
#   Obtaining dependency information for regex!=2019.12.17 from https://files.pythonhosted.org/packages/23/d3/65db07106b4584b62b1ec0061277c54f565da92d91f0a211057faccb841b/regex-2024.5.15-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Downloading regex-2024.5.15-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 3.5 MB/s eta 0:00:00
# Collecting safetensors>=0.4.1 (from transformers<5.0.0,>=4.34.0->sentence_transformers)
#   Obtaining dependency information for safetensors>=0.4.1 from https://files.pythonhosted.org/packages/da/e3/2b76cf399ae6f3e7bd2017543d1124138a1fdb2475f102b6d0be4e81b42a/safetensors-0.4.3-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Downloading safetensors-0.4.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting tokenizers<0.20,>=0.19 (from transformers<5.0.0,>=4.34.0->sentence_transformers)
#   Obtaining dependency information for tokenizers<0.20,>=0.19 from https://files.pythonhosted.org/packages/74/d1/f4e1e950adb36675dfd8f9d0f4be644f3f3aaf22a5677a4f5c81282b662e/tokenizers-0.19.1-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Downloading tokenizers-0.19.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->sentence_transformers)
#   Obtaining dependency information for joblib>=1.2.0 from https://files.pythonhosted.org/packages/91/29/df4b9b42f2be0b623cbd5e2140cafcaa2bef0759a00b7b70104dcfe2fb51/joblib-1.4.2-py3-none-any.whl.metadata
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence_transformers)
#   Obtaining dependency information for threadpoolctl>=3.1.0 from https://files.pythonhosted.org/packages/4b/2c/ffbf7a134b9ab11a67b0cf0726453cedd9c5043a4fe7a35d1cefa9a1bcfb/threadpoolctl-3.5.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alonagmon/virtualenvs/py312/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2023.11.17)
# Collecting mpmath<1.4.0,>=1.1.0 (from sympy->torch>=1.11.0->sentence_transformers)
#   Obtaining dependency information for mpmath<1.4.0,>=1.1.0 from https://files.pythonhosted.org/packages/43/e3/7d92a15f894aa0c9c4b49b8ee9ac9850d6e63b03c9c32c0367a13ae62209/mpmath-1.3.0-py3-none-any.whl.metadata
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 3.3 MB/s eta 0:00:00a 0:00:01
# Downloading huggingface_hub-0.23.4-py3-none-any.whl (402 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.6/402.6 kB 6.0 MB/s eta 0:00:00ta 0:00:01
# Downloading torch-2.3.1-cp312-none-macosx_11_0_arm64.whl (61.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 MB 9.8 MB/s eta 0:00:00:00:0100:01
# Downloading transformers-4.42.3-py3-none-any.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 7.9 MB/s eta 0:00:0000:0100:01m
# Downloading scikit_learn-1.5.1-cp312-cp312-macosx_12_0_arm64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 8.7 MB/s eta 0:00:0000:0100:01
# Downloading scipy-1.14.0-cp312-cp312-macosx_14_0_arm64.whl (23.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 10.3 MB/s eta 0:00:0000:0100:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 29.5 MB/s eta 0:00:00
# Downloading regex-2024.5.15-cp312-cp312-macosx_11_0_arm64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.5/278.5 kB 8.5 MB/s eta 0:00:00
# Downloading safetensors-0.4.3-cp312-cp312-macosx_11_0_arm64.whl (411 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.1/411.1 kB 8.7 MB/s eta 0:00:00a 0:00:01
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading tokenizers-0.19.1-cp312-cp312-macosx_11_0_arm64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 10.0 MB/s eta 0:00:00a 0:00:01
# Downloading filelock-3.15.4-py3-none-any.whl (16 kB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Downloading sympy-1.12.1-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 8.8 MB/s eta 0:00:0000:0100:01m
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, threadpoolctl, sympy, scipy, safetensors, regex, networkx, joblib, filelock, torch, scikit-learn, huggingface-hub, tokenizers, transformers, sentence_transformers
# Successfully installed filelock-3.15.4 huggingface-hub-0.23.4 joblib-1.4.2 mpmath-1.3.0 networkx-3.3 regex-2024.5.15 safetensors-0.4.3 scikit-learn-1.5.1 scipy-1.14.0 sentence_transformers-3.0.1 sympy-1.12.1 threadpoolctl-3.5.0 tokenizers-0.19.1 torch-2.3.1 transformers-4.42.3
#
# [notice] A new release of pip is available: 23.2.1 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("all-MiniLM-L6-v2")

# The sentences to encode
sentences = [
    "I really like animals and especially dogs.",
    "It's so sunny outside!",
]

# 2. Calculate embeddings by calling model.encode()
embeddings = model.encode(sentences, normalize_embeddings=True)
print(embeddings.shape)
# Out:
# (2, 384)

# %%
type(embeddings[0])
# Out:
# numpy.ndarray

# %%
tbl.search(embeddings[0]).limit(1).to_pandas()
# Out:
#                                       filename  \
# 0  embedding_files/embedding_content_10350.txt
#
#                                               vector  _distance
# 0  [0.07240148, -0.037085783, 0.13226897, 0.05840...   0.840982

# %%
# read the content of this file: embedding_files/embedding_content_99996.txt
filename = "embedding_files/embedding_content_10350.txt"
with open(filename , "r") as f:
    content = f.read()
    print(content)
# Out:
# --- PETS ---
# Horses require a large amount of outdoor space.
# Fish are popular pets for small apartments.
# Cats love scratching posts that mimic trees.
# Fish are popular pets for small apartments.
# Dogs often bark to express their feelings.
# Rabbits thrive on a diet rich in hay.
# Dogs often bark to express their feelings.
# Fish are popular pets for small apartments.
# Guinea pigs make a series of interesting vocalizations.
# Snakes can be intriguing, though somewhat unconventional pets.
# Turtles can live for many decades with proper care.
# Cats love scratching posts that mimic trees.
# Snakes can be intriguing, though somewhat unconventional pets.
# Snakes can be intriguing, though somewhat unconventional pets.
# Cats love scratching posts that mimic trees.
# Dogs often bark to express their feelings.
# Turtles can live for many decades with proper care.
# Guinea pigs make a series of interesting vocalizations.
# Snakes can be intriguing, though somewhat unconventional pets.
# Fish are popular pets for small apartments.
# Ferrets are playful animals that enjoy interacting with humans.
# Rabbits thrive on a diet rich in hay.
# Turtles can live for many decades with proper care.
# Cats love scratching posts that mimic trees.
# Cats love scratching posts that mimic trees.
# Parrots can mimic human speech quite accurately.
# Horses require a large amount of outdoor space.
# Fish are popular pets for small apartments.
# Parrots can mimic human speech quite accurately.
# Guinea pigs make a series of interesting vocalizations.
# Dogs often bark to express their feelings.
# Turtles can live for many decades with proper care.
# Dogs often bark to express their feelings.
# Turtles can live for many decades with proper care.
# Cats love scratching posts that mimic trees.
# Ferrets are playful animals that enjoy interacting with humans.
# Snakes can be intriguing, though somewhat unconventional pets.
# Guinea pigs make a series of interesting vocalizations.
# Snakes can be intriguing, though somewhat unconventional pets.
# Rabbits thrive on a diet rich in hay.
# Fish are popular pets for small apartments.
# Turtles can live for many decades with proper care.
# Horses require a large amount of outdoor space.
# Ferrets are playful animals that enjoy interacting with humans.
# Parrots can mimic human speech quite accurately.
# Dogs often bark to express their feelings.
# Guinea pigs make a series of interesting vocalizations.
# Dogs often bark to express their feelings.
# Horses require a large amount of outdoor space.
# Snakes can be intriguing, though somewhat unconventional pets.
# Snakes can be intriguing, though somewhat unconventional pets.
# Dogs often bark to express their feelings.
# Snakes can be intriguing, though somewhat unconventional pets.
# Cats love scratching posts that mimic trees.
# Dogs often bark to express their feelings.
# Dogs often bark to express their feelings.
# Turtles can live for many decades with proper care.
# Guinea pigs make a series of interesting vocalizations.
# Dogs often bark to express their feelings.
# Cats love scratching posts that mimic trees.
# Cats love scratching posts that mimic trees.
# Cats love scratching posts that mimic trees.
# Rabbits thrive on a diet rich in hay.
# Cats love scratching posts that mimic trees.
# Cats love scratching posts that mimic trees.
# Parrots can mimic human speech quite accurately.
# Rabbits thrive on a diet rich in hay.
# Ferrets are playful animals that enjoy interacting with humans.
# Ferrets are playful animals that enjoy interacting with humans.
# Turtles can live for many decades with proper care.
# Parrots can mimic human speech quite accurately.
# Fish are popular pets for small apartments.
# Turtles can live for many decades with proper care.
# Snakes can be intriguing, though somewhat unconventional pets.
# Turtles can live for many decades with proper care.
# Fish are popular pets for small apartments.
# Turtles can live for many decades with proper care.
# Fish are popular pets for small apartments.
# Dogs often bark to express their feelings.
# Turtles can live for many decades with proper care.
# Guinea pigs make a series of interesting vocalizations.
# Ferrets are playful animals that enjoy interacting with humans.
# Parrots can mimic human speech quite accurately.
# Ferrets are playful animals that enjoy interacting with humans.
# Dogs often bark to express their feelings.
# Horses require a large amount of outdoor space.
# Turtles can live for many decades with proper care.
# Turtles can live for many decades with proper care.
# Turtles can live for many decades with proper care.
# Turtles can live for many decades with proper care.
# Ferrets are playful animals that enjoy interacting with humans.
# Fish are popular pets for small apartments.
# Rabbits thrive on a diet rich in hay.
# Snakes can be intriguing, though somewhat unconventional pets.
# Rabbits thrive on a diet rich in hay.
# Snakes can be intriguing, though somewhat unconventional pets.
# Guinea pigs make a series of interesting vocalizations.
# Guinea pigs make a series of interesting vocalizations.
# Horses require a large amount of outdoor space.
# Snakes can be intriguing, though somewhat unconventional pets.
# Parrots can mimic human speech quite accurately.
# Horses require a large amount of outdoor space.
# Rabbits thrive on a diet rich in hay.
# Fish are popular pets for small apartments.
# Guinea pigs make a series of interesting vocalizations.
# Parrots can mimic human speech quite accurately.
# Turtles can live for many decades with proper care.
# Cats love scratching posts that mimic trees.
# Dogs often bark to express their feelings.
# Rabbits thrive on a diet rich in hay.
# Fish are popular pets for small apartments.
# Ferrets are playful animals that enjoy interacting with humans.
# Dogs often bark to express their feelings.
# Parrots can mimic human speech quite accurately.
# Horses require a large amount of outdoor space.
# Horses require a large amount of outdoor space.
# Snakes can be intriguing, though somewhat unconventional pets.
# Horses require a large amount of outdoor space.
# Ferrets are playful animals that enjoy interacting with humans.
# Turtles can live for many decades with proper care.
# Ferrets are playful animals that enjoy interacting with humans.
# Turtles can live for many decades with proper care.
# Ferrets are playful animals that enjoy interacting with humans.
# Dogs often bark to express their feelings.
# Snakes can be intriguing, though somewhat unconventional pets.
# Dogs often bark to express their feelings.
# Cats love scratching posts that mimic trees.
# Cats love scratching posts that mimic trees.
# Fish are popular pets for small apartments.
# Parrots can mimic human speech quite accurately.
# Parrots can mimic human speech quite accurately.
# Guinea pigs make a series of interesting vocalizations.
# Turtles can live for many decades with proper care.
# Turtles can live for many decades with proper care.
# Fish are popular pets for small apartments.
# Turtles can live for many decades with proper care.
# Dogs often bark to express their feelings.
# Fish are popular pets for small apartments.
# Fish are popular pets for small apartments.
# Fish are popular pets for small apartments.
# Guinea pigs make a series of interesting vocalizations.
# Guinea pigs make a series of interesting vocalizations.
# Fish are popular pets for small apartments.
# Dogs often bark to express their feelings.
# Parrots can mimic human speech quite accurately.
# Ferrets are playful animals that enjoy interacting with humans.
# Horses require a large amount of outdoor space.
# Snakes can be intriguing, though somewhat unconventional pets.
# Cats love scratching posts that mimic trees.
# Ferrets are playful animals that enjoy interacting with humans.
# Fish are popular pets for small apartments.
# Turtles can live for many decades with proper care.
# Parrots can mimic human speech quite accurately.
# Guinea pigs make a series of interesting vocalizations.
# Parrots can mimic human speech quite accurately.
# Cats love scratching posts that mimic trees.
# Horses require a large amount of outdoor space.
# Parrots can mimic human speech quite accurately.
# Guinea pigs make a series of interesting vocalizations.
# Horses require a large amount of outdoor space.
# Guinea pigs make a series of interesting vocalizations.
# Guinea pigs make a series of interesting vocalizations.
# Horses require a large amount of outdoor space.
# Fish are popular pets for small apartments.
# Snakes can be intriguing, though somewhat unconventional pets.
# Fish are popular pets for small apartments.
# Guinea pigs make a series of interesting vocalizations.
# Snakes can be intriguing, though somewhat unconventional pets.
# Rabbits thrive on a diet rich in hay.
# Turtles can live for many decades with proper care.
# Guinea pigs make a series of interesting vocalizations.
# Turtles can live for many decades with proper care.
# Parrots can mimic human speech quite accurately.
# Snakes can be intriguing, though somewhat unconventional pets.
# Dogs often bark to express their feelings.
# Guinea pigs make a series of interesting vocalizations.
# Turtles can live for many decades with proper care.
# Turtles can live for many decades with proper care.
# Parrots can mimic human speech quite accurately.
# Horses require a large amount of outdoor space.
# Horses require a large amount of outdoor space.
# Horses require a large amount of outdoor space.
# Snakes can be intriguing, though somewhat unconventional pets.
# Horses require a large amount of outdoor space.
# Ferrets are playful animals that enjoy interacting with humans.
# Rabbits thrive on a diet rich in hay.
# Turtles can live for many decades with proper care.
# Fish are popular pets for small apartments.
# Parrots can mimic human speech quite accurately.
# Guinea pigs make a series of interesting vocalizations.
# Horses require a large amount of outdoor space.
# Parrots can mimic human speech quite accurately.
# Parrots can mimic human speech quite accurately.
# Snakes can be intriguing, though somewhat unconventional pets.
# Fish are popular pets for small apartments.
# Horses require a large amount of outdoor space.
# Parrots can mimic human speech quite accurately.
# Cats love scratching posts that mimic trees.
# Horses require a large amount of outdoor space.
# Ferrets are playful animals that enjoy interacting with humans.

# %%
filename = "embedding_files/embedding_content_10350.txt"
# count the number of words in the document without a counter
with open(filename , "r") as f:
    content = f.read()
    print(len(content.split()))
# Out:
# 1565

# %%
len(Counter(tokens))
# Out:
# 68
